# %% [markdown]
# <h1 style="text-align:left;">My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <p style="font-weight:bold;">Jonathan Clark</p>
# <p>Data Scientist</p>

# %% [markdown]
# <i>I am interested in data sciene because it uses math and analytics to find insights in to help solve problems so that businesses can thrive.<i>

# %% [markdown]
# <h3>The next line squares the number 5 by using the exponent operator '**'.</h3>

# %%
x = 5 ** 2
print(x)
# Out:
# 25

# %% [markdown]
# (1) Horizontal Rule
# <hr>
#
#
# (2) Bulleted List with Hyperlinks
# <ul>
#     <li><a href="https://github.com/" target="_blank" rel="noopener noreferrer">GitHub</a></li>
#     <li><a href="https://github.com/" target="_blank" rel="noopener noreferrer">GitHub</a></li>
# </ul>
#
#
# (3) Image (honeybees.png)
# ![honeybees.png](attachment:honeybees.png)
